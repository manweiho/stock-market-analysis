# %% [markdown]
# <a href="https://colab.research.google.com/github/manweiho/stock-market-analysis/blob/main/stock-market-analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the packages
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web

# %%
#Set stock dataset start date and end date
start = dt.datetime(2017,1,1)
end = dt.datetime(2022,12,31)

# %%
#Create HOG,TM and F stock's dataframe
df = web.DataReader('HOG', 'stooq', start, end)
df
# Out:
#                Open     High      Low    Close        Volume
# Date
# 2022-12-30  40.6000  41.6300  40.3700  41.6000  1.027345e+06
# 2022-12-29  40.8500  41.2498  40.6520  41.0000  9.953710e+05
# 2022-12-28  41.0700  41.2000  39.8400  40.2900  1.093171e+06
# 2022-12-27  41.4500  41.5900  40.6820  41.0100  7.937210e+05
# 2022-12-23  41.1500  41.4300  40.6020  41.4200  1.089288e+06
# ...             ...      ...      ...      ...           ...
# 2017-01-09  50.8166  50.8769  49.7058  49.9806  4.201843e+06
# 2017-01-06  50.7109  51.2099  49.8007  50.7998  2.123034e+06
# 2017-01-05  50.9668  51.5647  50.7209  51.2683  1.622718e+06
# 2017-01-04  50.9372  51.3533  50.2919  51.2189  1.904967e+06
# 2017-01-03  50.4520  51.2516  50.3927  50.6605  1.718918e+06
#
# [1510 rows x 5 columns]

# %%
df1 = web.DataReader('TM', 'stooq', start, end)
df1
# Out:
#                Open      High       Low    Close         Volume
# Date
# 2022-12-30  136.880  137.3999  136.0000  136.580  168810.000000
# 2022-12-29  135.940  137.4900  135.9100  137.410  249482.000000
# 2022-12-28  136.000  136.7700  133.9001  134.130  236940.000000
# 2022-12-27  136.120  136.9650  135.8389  136.160  137626.000000
# 2022-12-23  137.040  137.7550  136.1900  137.140  149383.000000
# ...             ...       ...       ...      ...            ...
# 2017-01-09  102.996  103.3920  102.9860  103.214  157494.303744
# 2017-01-06  103.303  103.6490  102.9270  103.560  199024.754385
# 2017-01-05  104.470  104.6380  103.7080  103.827  608009.233842
# 2017-01-04  103.679  104.5590  103.5700  104.470  290721.240247
# 2017-01-03  101.858  102.2930  101.5810  102.185  236636.646810
#
# [1510 rows x 5 columns]

# %%
df2 = web.DataReader('F', 'stooq', start, end)
df2
# Out:
#                 Open      High       Low     Close        Volume
# Date
# 2022-12-30  11.40000  11.64000  11.39000  11.63000  3.923222e+07
# 2022-12-29  11.08000  11.55000  11.05000  11.54000  5.355026e+07
# 2022-12-28  11.18000  11.25000  10.90000  10.95000  4.937540e+07
# 2022-12-27  11.28000  11.39000  11.13000  11.20000  4.483743e+07
# 2022-12-23  11.27000  11.40000  11.22000  11.36000  3.820065e+07
# ...              ...       ...       ...       ...           ...
# 2017-01-09  10.04080  10.09480   9.91347   9.91347  5.001689e+07
# 2017-01-06  10.04680  10.08000   9.92129  10.01640  5.133211e+07
# 2017-01-05  10.36710  10.37690   9.91347  10.02420  9.631945e+07
# 2017-01-04  10.02420  10.41610   9.99967  10.33680  9.879221e+07
# 2017-01-03   9.57639   9.89093   9.52152   9.88309  5.157833e+07
#
# [1510 rows x 5 columns]

# %%
df=df.reindex(index=df.index[::-1])
df
# Out:
#                Open     High      Low    Close        Volume
# Date
# 2017-01-03  50.4520  51.2516  50.3927  50.6605  1.718918e+06
# 2017-01-04  50.9372  51.3533  50.2919  51.2189  1.904967e+06
# 2017-01-05  50.9668  51.5647  50.7209  51.2683  1.622718e+06
# 2017-01-06  50.7109  51.2099  49.8007  50.7998  2.123034e+06
# 2017-01-09  50.8166  50.8769  49.7058  49.9806  4.201843e+06
# ...             ...      ...      ...      ...           ...
# 2022-12-23  41.1500  41.4300  40.6020  41.4200  1.089288e+06
# 2022-12-27  41.4500  41.5900  40.6820  41.0100  7.937210e+05
# 2022-12-28  41.0700  41.2000  39.8400  40.2900  1.093171e+06
# 2022-12-29  40.8500  41.2498  40.6520  41.0000  9.953710e+05
# 2022-12-30  40.6000  41.6300  40.3700  41.6000  1.027345e+06
#
# [1510 rows x 5 columns]

# %%
df1=df1.reindex(index=df1.index[::-1])
df1
# Out:
#                Open      High       Low    Close         Volume
# Date
# 2017-01-03  101.858  102.2930  101.5810  102.185  236636.646810
# 2017-01-04  103.679  104.5590  103.5700  104.470  290721.240247
# 2017-01-05  104.470  104.6380  103.7080  103.827  608009.233842
# 2017-01-06  103.303  103.6490  102.9270  103.560  199024.754385
# 2017-01-09  102.996  103.3920  102.9860  103.214  157494.303744
# ...             ...       ...       ...      ...            ...
# 2022-12-23  137.040  137.7550  136.1900  137.140  149383.000000
# 2022-12-27  136.120  136.9650  135.8389  136.160  137626.000000
# 2022-12-28  136.000  136.7700  133.9001  134.130  236940.000000
# 2022-12-29  135.940  137.4900  135.9100  137.410  249482.000000
# 2022-12-30  136.880  137.3999  136.0000  136.580  168810.000000
#
# [1510 rows x 5 columns]

# %%
df2=df2.reindex(index=df2.index[::-1])
df2
# Out:
#                 Open      High       Low     Close        Volume
# Date
# 2017-01-03   9.57639   9.89093   9.52152   9.88309  5.157833e+07
# 2017-01-04  10.02420  10.41610   9.99967  10.33680  9.879221e+07
# 2017-01-05  10.36710  10.37690   9.91347  10.02420  9.631945e+07
# 2017-01-06  10.04680  10.08000   9.92129  10.01640  5.133211e+07
# 2017-01-09  10.04080  10.09480   9.91347   9.91347  5.001689e+07
# ...              ...       ...       ...       ...           ...
# 2022-12-23  11.27000  11.40000  11.22000  11.36000  3.820065e+07
# 2022-12-27  11.28000  11.39000  11.13000  11.20000  4.483743e+07
# 2022-12-28  11.18000  11.25000  10.90000  10.95000  4.937540e+07
# 2022-12-29  11.08000  11.55000  11.05000  11.54000  5.355026e+07
# 2022-12-30  11.40000  11.64000  11.39000  11.63000  3.923222e+07
#
# [1510 rows x 5 columns]

# %%
#Export to a csv
df.to_csv('HOG.csv')
df1.to_csv('TM.csv')
df2.to_csv('F.csv')

# %%
#Reduce decimal places for easier viewing
pd.set_option("display.precision", 2)

# %%
df = pd.read_csv('HOG.csv', parse_dates=True, index_col=0)
df
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2017-01-03  50.45  51.25  50.39  50.66  1.72e+06
# 2017-01-04  50.94  51.35  50.29  51.22  1.90e+06
# 2017-01-05  50.97  51.56  50.72  51.27  1.62e+06
# 2017-01-06  50.71  51.21  49.80  50.80  2.12e+06
# 2017-01-09  50.82  50.88  49.71  49.98  4.20e+06
# ...           ...    ...    ...    ...       ...
# 2022-12-23  41.15  41.43  40.60  41.42  1.09e+06
# 2022-12-27  41.45  41.59  40.68  41.01  7.94e+05
# 2022-12-28  41.07  41.20  39.84  40.29  1.09e+06
# 2022-12-29  40.85  41.25  40.65  41.00  9.95e+05
# 2022-12-30  40.60  41.63  40.37  41.60  1.03e+06
#
# [1510 rows x 5 columns]

# %%
#define the graph style for Graphs
style.use('classic')

# %%
#Plot graph
df['Close'].plot()
plt.title('Harley-Davidson - 5 Year Chart of performance');
plt.ylabel("Stock Price($)")
plt.show()

# %%
df1['Close'].plot()
plt.title(' Toyota Motor Company - 5 Year Chart of performance');
plt.ylabel("Stock Price($)")
plt.show()

# %%
df2['Close'].plot()
plt.title(' Ford Motor Company -5 Year Chart of performance');
plt.ylabel("Stock Price($)")
plt.show()

# %%
#Create a new column of 100 day mean
df['100ma']  = df['Close'].rolling(window=100, min_periods=0).mean()
df.dropna()
# Out:
#              Open   High    Low  Close    Volume  100ma
# Date
# 2017-01-03  50.45  51.25  50.39  50.66  1.72e+06  50.66
# 2017-01-04  50.94  51.35  50.29  51.22  1.90e+06  50.94
# 2017-01-05  50.97  51.56  50.72  51.27  1.62e+06  51.05
# 2017-01-06  50.71  51.21  49.80  50.80  2.12e+06  50.99
# 2017-01-09  50.82  50.88  49.71  49.98  4.20e+06  50.79
# ...           ...    ...    ...    ...       ...    ...
# 2022-12-23  41.15  41.43  40.60  41.42  1.09e+06  41.22
# 2022-12-27  41.45  41.59  40.68  41.01  7.94e+05  41.26
# 2022-12-28  41.07  41.20  39.84  40.29  1.09e+06  41.29
# 2022-12-29  40.85  41.25  40.65  41.00  9.95e+05  41.32
# 2022-12-30  40.60  41.63  40.37  41.60  1.03e+06  41.37
#
# [1510 rows x 6 columns]

# %%
df1['100ma'] = df1['Close'].rolling(window=100, min_periods=0).mean()
df1.dropna()
# Out:
#               Open    High     Low   Close     Volume   100ma
# Date
# 2017-01-03  101.86  102.29  101.58  102.19  236636.65  102.19
# 2017-01-04  103.68  104.56  103.57  104.47  290721.24  103.33
# 2017-01-05  104.47  104.64  103.71  103.83  608009.23  103.49
# 2017-01-06  103.30  103.65  102.93  103.56  199024.75  103.51
# 2017-01-09  103.00  103.39  102.99  103.21  157494.30  103.45
# ...            ...     ...     ...     ...        ...     ...
# 2022-12-23  137.04  137.75  136.19  137.14  149383.00  143.04
# 2022-12-27  136.12  136.97  135.84  136.16  137626.00  142.83
# 2022-12-28  136.00  136.77  133.90  134.13  236940.00  142.60
# 2022-12-29  135.94  137.49  135.91  137.41  249482.00  142.41
# 2022-12-30  136.88  137.40  136.00  136.58  168810.00  142.25
#
# [1510 rows x 6 columns]

# %%
df2['100ma'] = df2['Close'].rolling(window=100, min_periods=0).mean()
df2.dropna()
# Out:
#              Open   High    Low  Close    Volume  100ma
# Date
# 2017-01-03   9.58   9.89   9.52   9.88  5.16e+07   9.88
# 2017-01-04  10.02  10.42  10.00  10.34  9.88e+07  10.11
# 2017-01-05  10.37  10.38   9.91  10.02  9.63e+07  10.08
# 2017-01-06  10.05  10.08   9.92  10.02  5.13e+07  10.07
# 2017-01-09  10.04  10.09   9.91   9.91  5.00e+07  10.03
# ...           ...    ...    ...    ...       ...    ...
# 2022-12-23  11.27  11.40  11.22  11.36  3.82e+07  13.58
# 2022-12-27  11.28  11.39  11.13  11.20  4.48e+07  13.54
# 2022-12-28  11.18  11.25  10.90  10.95  4.94e+07  13.50
# 2022-12-29  11.08  11.55  11.05  11.54  5.36e+07  13.46
# 2022-12-30  11.40  11.64  11.39  11.63  3.92e+07  13.43
#
# [1510 rows x 6 columns]

# %%
start = dt.datetime.now() - dt.timedelta(days = 1 *365)
end = dt.datetime.now()

# %%
#Create a dataframe
HOG2021 = web.DataReader('HOG', 'stooq', start, end)
HOG2021
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2023-02-03  51.16  51.38  50.53  51.31  1.75e+06
# 2023-02-02  50.05  51.77  49.58  51.72  4.86e+06
# 2023-02-01  45.86  46.87  45.18  46.72  2.61e+06
# 2023-01-31  45.47  46.05  44.92  46.03  2.55e+06
# 2023-01-30  44.77  45.87  44.77  45.12  1.52e+06
# ...           ...    ...    ...    ...       ...
# 2022-02-11  41.97  42.06  40.57  41.07  2.29e+06
# 2022-02-10  42.06  43.77  41.81  41.92  3.28e+06
# 2022-02-09  41.43  43.14  41.13  42.65  4.15e+06
# 2022-02-08  39.36  41.12  37.91  41.08  9.75e+06
# 2022-02-07  35.46  36.36  34.95  35.56  3.03e+06
#
# [250 rows x 5 columns]

# %%
TM2021 = web.DataReader('TM', 'stooq', start, end)
TM2021
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2023-02-03  145.62  146.41  144.45  144.71  248148.00
# 2023-02-02  147.00  147.36  144.61  146.62  299387.00
# 2023-02-01  146.58  149.01  146.58  148.58  213278.00
# 2023-01-31  146.30  147.11  145.88  147.11  145793.00
# 2023-01-30  146.00  146.29  145.09  145.18  182444.00
# ...            ...     ...     ...     ...        ...
# 2022-02-11  192.39  194.12  189.87  190.67  232492.70
# 2022-02-10  192.93  195.21  192.19  192.35  425603.73
# 2022-02-09  199.98  201.79  198.26  199.23  346216.80
# 2022-02-08  197.88  198.60  195.91  198.20  291650.09
# 2022-02-07  196.05  196.31  194.45  195.15  179901.95
#
# [250 rows x 5 columns]

# %%
F2021 = web.DataReader('F', 'stooq', start, end)
F2021
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2023-02-03  13.05  13.61  12.78  13.23  1.66e+08
# 2023-02-02  14.17  14.60  14.03  14.32  1.03e+08
# 2023-02-01  13.52  13.99  13.49  13.79  7.06e+07
# 2023-01-31  13.39  13.57  13.25  13.51  8.31e+07
# 2023-01-30  13.01  13.20  12.86  12.89  6.45e+07
# ...           ...    ...    ...    ...       ...
# 2022-02-11  17.62  17.87  16.96  17.08  9.71e+07
# 2022-02-10  17.49  18.13  17.44  17.60  7.83e+07
# 2022-02-09  17.78  17.94  17.55  17.86  8.95e+07
# 2022-02-08  17.11  17.43  16.57  17.25  1.47e+08
# 2022-02-07  17.26  17.64  17.23  17.41  8.69e+07
#
# [250 rows x 5 columns]

# %%
HOG2021=HOG2021.reindex(index=HOG2021.index[::-1])
HOG2021
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2022-02-07  35.46  36.36  34.95  35.56  3.03e+06
# 2022-02-08  39.36  41.12  37.91  41.08  9.75e+06
# 2022-02-09  41.43  43.14  41.13  42.65  4.15e+06
# 2022-02-10  42.06  43.77  41.81  41.92  3.28e+06
# 2022-02-11  41.97  42.06  40.57  41.07  2.29e+06
# ...           ...    ...    ...    ...       ...
# 2023-01-30  44.77  45.87  44.77  45.12  1.52e+06
# 2023-01-31  45.47  46.05  44.92  46.03  2.55e+06
# 2023-02-01  45.86  46.87  45.18  46.72  2.61e+06
# 2023-02-02  50.05  51.77  49.58  51.72  4.86e+06
# 2023-02-03  51.16  51.38  50.53  51.31  1.75e+06
#
# [250 rows x 5 columns]

# %%
TM2021=TM2021.reindex(index=TM2021.index[::-1])
TM2021
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2022-02-07  196.05  196.31  194.45  195.15  179901.95
# 2022-02-08  197.88  198.60  195.91  198.20  291650.09
# 2022-02-09  199.98  201.79  198.26  199.23  346216.80
# 2022-02-10  192.93  195.21  192.19  192.35  425603.73
# 2022-02-11  192.39  194.12  189.87  190.67  232492.70
# ...            ...     ...     ...     ...        ...
# 2023-01-30  146.00  146.29  145.09  145.18  182444.00
# 2023-01-31  146.30  147.11  145.88  147.11  145793.00
# 2023-02-01  146.58  149.01  146.58  148.58  213278.00
# 2023-02-02  147.00  147.36  144.61  146.62  299387.00
# 2023-02-03  145.62  146.41  144.45  144.71  248148.00
#
# [250 rows x 5 columns]

# %%
F2021=F2021.reindex(index=F2021.index[::-1])
F2021
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2022-02-07  17.26  17.64  17.23  17.41  8.69e+07
# 2022-02-08  17.11  17.43  16.57  17.25  1.47e+08
# 2022-02-09  17.78  17.94  17.55  17.86  8.95e+07
# 2022-02-10  17.49  18.13  17.44  17.60  7.83e+07
# 2022-02-11  17.62  17.87  16.96  17.08  9.71e+07
# ...           ...    ...    ...    ...       ...
# 2023-01-30  13.01  13.20  12.86  12.89  6.45e+07
# 2023-01-31  13.39  13.57  13.25  13.51  8.31e+07
# 2023-02-01  13.52  13.99  13.49  13.79  7.06e+07
# 2023-02-02  14.17  14.60  14.03  14.32  1.03e+08
# 2023-02-03  13.05  13.61  12.78  13.23  1.66e+08
#
# [250 rows x 5 columns]

# %%
HOG2021['100ma']  = HOG2021['Close'].rolling(window=100, min_periods=0).mean()
HOG2021.dropna()
HOG2021
# Out:
#              Open   High    Low  Close    Volume  100ma
# Date
# 2022-02-07  35.46  36.36  34.95  35.56  3.03e+06  35.56
# 2022-02-08  39.36  41.12  37.91  41.08  9.75e+06  38.32
# 2022-02-09  41.43  43.14  41.13  42.65  4.15e+06  39.76
# 2022-02-10  42.06  43.77  41.81  41.92  3.28e+06  40.30
# 2022-02-11  41.97  42.06  40.57  41.07  2.29e+06  40.45
# ...           ...    ...    ...    ...       ...    ...
# 2023-01-30  44.77  45.87  44.77  45.12  1.52e+06  42.16
# 2023-01-31  45.47  46.05  44.92  46.03  2.55e+06  42.22
# 2023-02-01  45.86  46.87  45.18  46.72  2.61e+06  42.29
# 2023-02-02  50.05  51.77  49.58  51.72  4.86e+06  42.40
# 2023-02-03  51.16  51.38  50.53  51.31  1.75e+06  42.49
#
# [250 rows x 6 columns]

# %%
M2021['100ma'] = TM2021['Close'].rolling(window=100, min_periods=0).mean()
TM2021.dropna()
TM2021T
# Out:
#               Open    High     Low   Close     Volume   100ma
# Date
# 2022-02-07  196.05  196.31  194.45  195.15  179901.95  195.15
# 2022-02-08  197.88  198.60  195.91  198.20  291650.09  196.67
# 2022-02-09  199.98  201.79  198.26  199.23  346216.80  197.53
# 2022-02-10  192.93  195.21  192.19  192.35  425603.73  196.23
# 2022-02-11  192.39  194.12  189.87  190.67  232492.70  195.12
# ...            ...     ...     ...     ...        ...     ...
# 2023-01-30  146.00  146.29  145.09  145.18  182444.00  140.00
# 2023-01-31  146.30  147.11  145.88  147.11  145793.00  140.04
# 2023-02-01  146.58  149.01  146.58  148.58  213278.00  140.09
# 2023-02-02  147.00  147.36  144.61  146.62  299387.00  140.10
# 2023-02-03  145.62  146.41  144.45  144.71  248148.00  140.09
#
# [250 rows x 6 columns]

# %%
F2021['100ma'] = F2021['Close'].rolling(window=100, min_periods=0).mean()
F2021.dropna()
F2021
# Out:
#              Open   High    Low  Close    Volume  100ma
# Date
# 2022-02-07  17.26  17.64  17.23  17.41  8.69e+07  17.41
# 2022-02-08  17.11  17.43  16.57  17.25  1.47e+08  17.33
# 2022-02-09  17.78  17.94  17.55  17.86  8.95e+07  17.51
# 2022-02-10  17.49  18.13  17.44  17.60  7.83e+07  17.53
# 2022-02-11  17.62  17.87  16.96  17.08  9.71e+07  17.44
# ...           ...    ...    ...    ...       ...    ...
# 2023-01-30  13.01  13.20  12.86  12.89  6.45e+07  12.89
# 2023-01-31  13.39  13.57  13.25  13.51  8.31e+07  12.87
# 2023-02-01  13.52  13.99  13.49  13.79  7.06e+07  12.86
# 2023-02-02  14.17  14.60  14.03  14.32  1.03e+08  12.85
# 2023-02-03  13.05  13.61  12.78  13.23  1.66e+08  12.83
#
# [250 rows x 6 columns]

# %%
# plot 100 Day Simple moving average
HOG2021['100ma'].plot()
plt.title('Harley-Davidson - 100 Day Simple moving average');
plt.ylabel("Stock Price($)")
# Out:
# Text(0, 0.5, 'Stock Price($)')

# %%
TM2021['100ma'].plot()
plt.title(' Toyota Motor Company - 100 Day Simple moving average');
plt.ylabel("Stock Price($)")
# Out:
# Text(0, 0.5, 'Stock Price($)')

# %%
F2021['100ma'].plot()
plt.title(' Ford Motor Company - 100 Day Simple moving average');
plt.ylabel("Stock Price($) Ford Motor Company")
# Out:
# Text(0, 0.5, 'Stock Price($) Ford Motor Company')

# %%
#The size for our chart:
plt.figure(figsize = (12,6))
#Plotting Close and SMA lines:
plt.plot(HOG2021['Close'], 'r', label='HOG Adj Close', linewidth = 2)
plt.plot(HOG2021['100ma'],'g', label='100 day rolling SMA', linewidth = 1.5)

#Adding title and labels on the axes, making legend visible:
plt.xlabel('Date')
plt.ylabel('Adjusted closing price ($)')
plt.title('Harley-Davidson - Price with a single Simple Moving Average')
plt.legend();

# %%
#The size for our chart:
plt.figure(figsize = (12,6))
#Plotting Close and SMA lines:
plt.plot(TM2021['Close'], 'r', label='TM Adj Close', linewidth = 2)
plt.plot(TM2021['100ma'],'g', label='100 day rolling SMA', linewidth = 1.5)

#Adding title and labels on the axes, making legend visible:
plt.xlabel('Date')
plt.ylabel('Adjusted closing price ($)')
plt.title(' Toyota Motor Company - Price with a single Simple Moving Average')
plt.legend();

# %%
#The size for our chart:
plt.figure(figsize = (12,6))
#Plotting Close and SMA lines:
plt.plot(F2021['Close'], 'r', label='F Adj Close', linewidth = 2)
plt.plot(F2021['100ma'],'g', label='100 day rolling SMA', linewidth = 1.5)

#Adding title and labels on the axes, making legend visible:
plt.xlabel('Date')
plt.ylabel('Adjusted closing price ($)')
plt.title(' Ford Motor Company - Price with a single Simple Moving Average')
plt.legend();

# %%
ax1= plt.subplot2grid((8,1), (0,0), rowspan = 5, colspan =1)
ax2= plt.subplot2grid((8,1), (6,0), rowspan = 1, colspan =1)

# %%
ax1.plot(df.index, df['Close'])
ax1.plot(df.index, df['100ma'])
ax2.bar(df.index, df['Volume'])
# Out:
# <BarContainer object of 1510 artists>

# %%
#The size for our chart:
plt.figure(figsize = (12,6))
#Plotting Adj Close and SMA lines:
ax1 = plt.subplot2grid((8,1),(0,0),rowspan=5,colspan=1)
ax2 = plt.subplot2grid((8,1),(6,0),rowspan=3,colspan=1, sharex=ax1)

ax1.plot(df.index,df['Close'], 'r',label='Adjusted Close')
ax1.plot(df.index,df['100ma'], 'g', label= "100 Moving Average")
plt.xlabel('Date')
#ax1.set_xlabel('Date')
ax1.set_ylabel('Adjusted closing price ($)')
ax1.set_title('Adjusted Close and 100 day Moving Average for Harley-Davidson Company')
ax1.legend()

ax2.bar(df.index,df['Volume'], label = "Volume", color='b')
ax2.legend()

plt.show()

# %%
ax1.plot(df1.index, df1['Close'])
ax1.plot(df1.index, df1['100ma'])
ax2.bar(df1.index, df1['Volume'])
# Out:
# <BarContainer object of 1510 artists>

# %%
#The size for our chart:
plt.figure(figsize = (12,6))
#Plotting Adj Close and SMA lines:
ax1 = plt.subplot2grid((8,1),(0,0),rowspan=5,colspan=1)
ax2 = plt.subplot2grid((8,1),(6,0),rowspan=3,colspan=1, sharex=ax1)

ax1.plot(df1.index,df1['Close'], 'r',label='Adjusted Close')
ax1.plot(df1.index,df1['100ma'], 'g', label= "100 Moving Average")
plt.xlabel('Date')
#ax1.set_xlabel('Date')
ax1.set_ylabel('Adjusted closing price ($)')
ax1.set_title('Adjusted Close and 100 day Moving Average for Toyota Motor Company')
ax1.legend()

ax2.bar(df.index,df1['Volume'], label = "Volume", color='b')
ax2.legend()

plt.show()

# %%
ax1.plot(df2.index, df2['Close'])
ax1.plot(df2.index, df2['100ma'])
ax2.bar(df2.index, df2['Volume'])
# Out:
# <BarContainer object of 1510 artists>

# %%
#The size for our chart:
plt.figure(figsize = (12,6))
#Plotting Adj Close and SMA lines:
ax1 = plt.subplot2grid((8,1),(0,0),rowspan=5,colspan=1)
ax2 = plt.subplot2grid((8,1),(6,0),rowspan=3,colspan=1, sharex=ax1)

ax1.plot(df2.index,df2['Close'], 'r',label='Adjusted Close')
ax1.plot(df2.index,df2['100ma'], 'g', label= "100 Moving Average")
plt.xlabel('Date')
#ax1.set_xlabel('Date')
ax1.set_ylabel('Adjusted closing price ($)')
ax1.set_title('Adjusted Close and 100 day Moving Average for Ford Motor Company')
ax1.legend()

ax2.bar(df.index,df['Volume'], label = "Volume", color='b')
ax2.legend()

plt.show()
